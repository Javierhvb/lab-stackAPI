# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
import sys
# !{sys.executable} -m pip install stackapi
from stackapi import StackAPI
import datetime
import time
import pandas as pd
import json

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
SITE  = StackAPI('stackoverflow')
question1 = SITE.fetch('questions', fromdate= datetime.datetime(2020,3,15), todate=datetime.datetime(2020,4,16), min=20, sort='votes')
question1['items']
# Out:
# [{'tags': ['c', 'nmap'],
#   'owner': {'reputation': 1319,
#    'user_id': 12134095,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/K1trV.jpg?s=128&g=1',
#    'display_name': 'DDiamond',
#    'link': 'https://stackoverflow.com/users/12134095/ddiamond'},
#   'is_answered': True,
#   'view_count': 9967,
#   'accepted_answer_id': 60902078,
#   'answer_count': 4,
#   'score': 136,
#   'last_activity_date': 1586350035,
#   'creation_date': 1585403515,
#   'last_edit_date': 1585918728,
#   'question_id': 60902001,
#   'link': 'https://stackoverflow.com/questions/60902001/why-have-i-i-right-after-each-other',
#   'title': 'Why have i++; i--; right after each other?'},
#  {'tags': ['assembly', 'x86', 'paging', 'virtualization', 'kvm'],
#   'owner': {'reputation': 563,
#    'user_id': 13181277,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/421d18ea864c1df9e1bb98e931ba106b?s=128&d=identicon&r=PG&f=1',
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
question2 = SITE.fetch('questions', fromdate=datetime.datetime.today().strftime('%Y-%m-%d') , min=5, tagged='python', sort='votes')
cleaned = question2['items']
print(f'The id of the most voted question today is ', lst[0]['question_id'])
# Out:
# The id of the most voted question today is  61227617

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
question3 = SITE.fetch('answers', ids = [6784, 6473])
question3['items']
# Out:
# [{'owner': {'reputation': 28695,
#    'user_id': 758,
#    'user_type': 'registered',
#    'accept_rate': 77,
#    'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#    'display_name': 'Mark Renouf',
#    'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#   'is_accepted': False,
#   'score': 0,
#   'last_activity_date': 1218291583,
#   'creation_date': 1218291583,
#   'answer_id': 6784,
#   'question_id': 6778}]
